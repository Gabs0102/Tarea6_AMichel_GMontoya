# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Alejandro Michel Marrón.
#
# **Fecha:** 15 de octubre del 2020.
#
# **Expediente** : IF719889.
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Github:** https://github.com/HKael/Tarea6_AMichel_GMontoya
#
# # Tarea 6: Clase 13

# %%
# Importamos librerías a trabajar en todas las simulaciones
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st     # Librería estadística
from scipy.stats import beta,triang
from math import factorial as fac # Importo la operación factorial
from scipy.special import comb # Importamos la función combinatoria

# %matplotlib inline

from numpy import sqrt   # leave this outside the function
from scipy.optimize import fsolve

from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# ### Ejercicio 1:
# Suponer que $T$ distribuye beta donde la media es $\mu_p$ y varianza $\sigma_p^2$ y responder cual es la probabilidad $P(T\leq d)$.

# %%
Image(url= "https://i.imgur.com/agVvw1F.png")
# Out:
# <img src="https://i.imgur.com/agVvw1F.png"/>

# %% [markdown]
# > **Ayuda**: - Aprender a utlizar el solucionador de ecuaciones no lineales https://stackoverflow.com/questions/19843116/passing-arguments-to-fsolve
# - Leer el help de la función beta del paquete estadístico para aprender a graficar funciones beta en un intervalo diferente a 0 y 1.

# %%
# Solución Alejandro Michel
#Datos con los que contamos de manera previa
u = 44; sigma = np.sqrt(9); d = 47; a = 40; b = 49
vec = np.array([1,1])

#Función a utilizar para resolver el ejercicio, Alpha y Beta
def getAlphaBeta(z : "Vector (Alpha,Beta)"):
    return [u-((a*z[1]+b*z[0])/(z[0]+z[1])), sigma**2-((z[0]*z[1])*(b-a)**2)/((1+z[0]+z[1])*(z[0]+z[1])**2)]

fun = fsolve(getAlphaBeta, vec)
print("Alpha = ", fun[0].round(6))
print("Beta = ", fun[1].round(6))

#Funciones de paquete estadistico beta.pdf(y, a, b) / scale with y = (x - loc) / scale  y cdf(x, a, b, loc=0, scale=1)
x = np.linspace(a,b,10000)
loc = a
scale = (b-a)
Y = (x -loc) / scale
bpdf = beta.pdf(x, fun[0], fun[1], loc, scale)
bcdf = beta.cdf(Y, fun[0], fun[1])

#Probabilidad
bcdf2 = beta.cdf(d, fun[0], fun[1], loc, scale)
print('P(T <= d) es ',bcdf2.round(5)*100,'%')

#Grafica
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,8))
ax1.plot(x, bpdf)
plt.title('Probability density function')
ax2.plot(x, bcdf)
plt.title("Cumulative distribution function")
plt.show()
# Out:
# Alpha =  0.54321
# Beta =  0.679012
# P(T <= d) es  76.773 %

# %%
## GABY 

p = 49 #b
o = 40 #a
mu= 44
s = np.sqrt(9)
d = 47

v = np.array([1,1])
def AlphaBeta (z : 'vector (alpha, beta)'):
    return [u-((o*z[1]+p*z[0])/(z[0]+z[1])), s**2-((z[0]*z[1]*(p-o)**2)/((1+z[0]+z[1])*(z[0]+z[1])**2))]
    
funs= fsolve(AlphaBeta,v)
print('alpha = ', funs[0].round(6))
print('beta = ', funs[1].round(6))

x = np.linspace(o,p,10000)
loc = o
scale = (p-o)
c = (x-loc)/scale

pp = beta.pdf(x, funs[0], funs[1], loc, scale)
pc = beta.cdf(c, funs[0], funs[1])

pc2 = beta.cdf(d, funs[0], funs[1], loc, scale)

print('La P(T <= d) es = ',pc2.round(5)*100,'%')
fig, (ax1, ax2) = plt.subplots(1,2,figsize =(16,8))
ax1.plot(x,pp)
ax2.plot(c,pc)
plt.show()
# Out:
# alpha =  0.54321
# beta =  0.679012
# La P(T <= d) es =  76.773 %

# %% [markdown]
# ### Ejercicio 2:
# Suponer que $T$ distribuye triangular donde el valor mas probable es $\mu_p$ el valor pesimista es $p=49$ y el valor optimista es $o=40$ y responder cual es la probabilidad $P(T\leq d)$. Nuevamente aprender a graficar una función triangular en un intervalro [a,b], usando el help.

# %%
# Solución Alejandro Michel
u = 44; sigma = np.sqrt(9); d = 47; a = 40; b = 49
#Funcion triangular en intervalo [a,b] --- triang.pdf(x, c, loc, scale) y triang.cdf(d, c, loc, scale)

x = np.linspace(a,b,10000)
loc = a
scale = (b-a)
c = (u-a)/ scale

tpdf = triang.pdf(x, c, loc, scale)
tcdf = triang.cdf(d, c, loc, scale)



#Grafica
plt.plot(x, tpdf)
plt.title('Función triangular en un intervalo [a,b]')
plt.show()

print('P(T <= d) es ',tcdf.round(5)*100,'%')
# Out:
# P(T <= d) es  91.111 %

# %%
## GABY 

p = 49
o = 40
mu= 44
s = np.sqrt(9)
d = 47

x = np.linspace(o,p,10000)
loc = o
scale = (p-o)
c = (u-o)/scale
pt = triang.cdf(d,c,loc,scale)
plt.plot(x, triang.pdf(x,c,loc,scale))
plt.show()

print('La P(T <= d) es = ',pt.round(5)*100,'%' )
# Out:
# La P(T <= d) es =  91.111 %
